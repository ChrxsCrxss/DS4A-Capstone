# %% [markdown]
# <a href="https://colab.research.google.com/github/ChrxsCrxss/DS4A-Capstone/blob/main/PopulationEstimatesClean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('../../data/raw/PopulationEstimates.xls')
# Out:
# --------------------------------------------------------
# FileNotFoundError      Traceback (most recent call last)
# <ipython-input-4-a8e503b94181> in <module>
# ----> 1 df = pd.read_excel('../../data/raw/PopulationEstimates.xls')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1070             else:
#    1071                 ext = inspect_excel_format(
# -> 1072                     content=path_or_buffer, storage_options=storage_options
#    1073                 )
#    1074
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/excel/_base.py in inspect_excel_format(path, content, storage_options)
#     948
#     949     with get_handle(
# --> 950         content_or_path, "rb", storage_options=storage_options, is_text=False
#     951     ) as handle:
#     952         stream = handle.handle
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/raw/PopulationEstimates.xls'

# %%
  df2=df.fillna(0).rename(columns=str.lower)#step 2 filled NAN with 0 and renamed columns to lower case, i was also able to get columns with values prior to 2013 by running .drop(columns=[''.,...])

# %%
df2.shape
# Out:
# (3273, 136)

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of       fipstxt state  ... r_net_mig_2018  r_net_mig_2019
# 0           0    US  ...       0.000000        0.000000
# 1        1000    AL  ...       1.773786        2.483744
# 2        1001    AL  ...       0.540916        4.560062
# 3        1003    AL  ...      24.727215       24.380567
# 4        1005    AL  ...      -8.754922       -5.165664
# ...       ...   ...  ...            ...             ...
# 3268    72145    PR  ...       0.000000        0.000000
# 3269    72147    PR  ...       0.000000        0.000000
# 3270    72149    PR  ...       0.000000        0.000000
# 3271    72151    PR  ...       0.000000        0.000000
# 3272    72153    PR  ...       0.000000        0.000000
#
# [3273 rows x 165 columns]>

# %%
df2
# Out:
#       fipstxt state  ... r_net_mig_2018  r_net_mig_2019
# 0           0    US  ...       0.000000        0.000000
# 1        1000    AL  ...       1.773786        2.483744
# 2        1001    AL  ...       0.540916        4.560062
# 3        1003    AL  ...      24.727215       24.380567
# 4        1005    AL  ...      -8.754922       -5.165664
# ...       ...   ...  ...            ...             ...
# 3268    72145    PR  ...       0.000000        0.000000
# 3269    72147    PR  ...       0.000000        0.000000
# 3270    72149    PR  ...       0.000000        0.000000
# 3271    72151    PR  ...       0.000000        0.000000
# 3272    72153    PR  ...       0.000000        0.000000
#
# [3273 rows x 165 columns]

# %%
df2.head(10)
# Out:
#    fipstxt state  ... r_net_mig_2018  r_net_mig_2019
# 0        0    US  ...       0.000000        0.000000
# 1     1000    AL  ...       1.773786        2.483744
# 2     1001    AL  ...       0.540916        4.560062
# 3     1003    AL  ...      24.727215       24.380567
# 4     1005    AL  ...      -8.754922       -5.165664
# 5     1007    AL  ...      -6.857092        1.831952
# 6     1009    AL  ...      -0.069229        1.124597
# 7     1011    AL  ...      -1.474201       -7.200986
# 8     1013    AL  ...     -10.071105       -6.294941
# 9     1015    AL  ...      -0.488995       -4.044995
#
# [10 rows x 165 columns]

# %%
df2.to_csv ('df2.csv')
