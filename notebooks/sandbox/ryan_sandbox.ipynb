# %%
import pandas as pd
import re
! pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 243 kB 3.0 MB/s eta 0:00:01
# ...

# %%
df = pd.read_excel('../../data/raw/Unemployment.xls')

# %%
pd.set_option('display.max_columns', 500)

# %%
df2 = df.copy()

# %%
df2.head(5)
# Out:
#   Unemployment and median household income for the U.S., States, and counties, 2000-19  \
# 0  Sources: Unemployment: U.S. Department of Labo...
# 1  For definitions of rural classifications, see ...
# 2  This table was prepared by USDA, Economic Rese...
# 3                                           fips_txt
# 4                                              00000
#
#   Unnamed: 1     Unnamed: 2                       Unnamed: 3  \
# 0        NaN            NaN                              NaN
# 1        NaN            NaN                              NaN
# 2        NaN            NaN                              NaN
# 3      Stabr      area_name  Rural_urban_continuum_code_2013
# 4         US  United States                              NaN
#
#                   Unnamed: 4  Unnamed: 5                 Unnamed: 6  \
# 0                        NaN         NaN                        NaN
# 1                        NaN         NaN                        NaN
# ...

# %%
## Rename columns to the fieds in row 3 then rename two of those columns to State and State_Couny
df2 = df2.rename(columns=df2.iloc[3])
df2 = df2.rename(columns={'Stabr': 'State', 'area_name': 'State_County'})

## drop the first 4 rows that contain all Nan values and/or column headers
df2 = df2.drop([0,1,2,3])

## Reset index to begin with 0 and drop previous index column 
df2 = df2.reset_index().drop('index', axis=1)

# %%
df2.head(5)
# Out:
#   fips_txt Stabr           area_name Rural_urban_continuum_code_2013  \
# 0    00000    US       United States                             NaN
# 1    01000    AL             Alabama                             NaN
# 2    01001    AL  Autauga County, AL                               2
# 3    01003    AL  Baldwin County, AL                               3
# 4    01005    AL  Barbour County, AL                               6
#
#   Urban_influence_code_2013 Metro_2013 Civilian_labor_force_2000  \
# 0                       NaN        NaN                 142601667
# 1                       NaN        NaN                   2133223
# 2                         2          1                     21720
# 3                         2          1                     69533
# 4                         6          0                     11373
#
#   Employed_2000 Unemployed_2000 Unemployment_rate_2000  \
# 0     136904680         5696987               3.995035
# ...

# %%
## drop columns before 2010
df2 = df2.drop(df2.columns[range(3,46)], axis=1)

# %%
df2.to_csv('../../data/processed/Unemployment_By_County_2010_to_2019')
